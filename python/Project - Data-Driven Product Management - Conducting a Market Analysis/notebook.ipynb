# %% [markdown]
# ![gym](gym.png)

# %% [markdown]
# You are a product manager for a fitness studio and are interested in understanding the current demand for digital fitness classes. You plan to conduct a market analysis in Python to gauge demand and identify potential areas for growth of digital products and services.
#
# ### The Data
#
# You are provided with a number of CSV files in the "Files/data" folder, which offer international and national-level data on Google Trends keyword searches related to fitness and related products.
#
# ### workout.csv
#
# | Column     | Description              |
# |------------|--------------------------|
# | `'month'` | Month when the data was measured. |
# | `'workout_worldwide'` | Index representing the popularity of the keyword 'workout', on a scale of 0 to 100. |
#
# ### three_keywords.csv
#
# | Column     | Description              |
# |------------|--------------------------|
# | `'month'` | Month when the data was measured. |
# | `'home_workout_worldwide'` | Index representing the popularity of the keyword 'home workout', on a scale of 0 to 100. |
# | `'gym_workout_worldwide'` | Index representing the popularity of the keyword 'gym workout', on a scale of 0 to 100. |
# | `'home_gym_worldwide'` | Index representing the popularity of the keyword 'home gym', on a scale of 0 to 100. |
#
# ### workout_geo.csv
#
# | Column     | Description              |
# |------------|--------------------------|
# | `'country'` | Country where the data was measured. |
# | `'workout_2018_2023'` | Index representing the popularity of the keyword 'workout' during the 5 year period. |
#
# ### three_keywords_geo.csv
#
# | Column     | Description              |
# |------------|--------------------------|
# | `'country'` | Country where the data was measured. |
# | `'home_workout_2018_2023'` | Index representing the popularity of the keyword 'home workout' during the 5 year period. |
# | `'gym_workout_2018_2023'` | Index representing the popularity of the keyword 'gym workout' during the 5 year period.  |
# | `'home_gym_2018_2023'` | Index representing the popularity of the keyword 'home gym' during the 5 year period. |

# %%
# Import the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Start coding here
workout = pd.read_csv('data/workout.csv')
print(workout.head(10))
print(workout.dtypes)
# Out:
#      month  workout_worldwide
# 0  2018-03                 59
# 1  2018-04                 61
# 2  2018-05                 57
# 3  2018-06                 56
# 4  2018-07                 51
# 5  2018-08                 58
# 6  2018-09                 50
# 7  2018-10                 49
# 8  2018-11                 47
# 9  2018-12                 48
# month                object
# workout_worldwide     int64
# dtype: object

# %%
# year_str step by step
workout['year'] = workout['month'].str.split('-').str[0]
print(workout.head(10))
workout_max = workout['workout_worldwide'].max()
print(workout_max)
workout_row = workout[workout['workout_worldwide'] == workout_max]
print(workout_row)
year_str = workout_row['year'].astype(str).iloc[0]
print(year_str)

# year_str in one step
#year_str = workout['month'][workout['workout_worldwide'] == workout['workout_worldwide'].max()].str.split('-').str[0]
#print(year_str)
# Out:
#      month  workout_worldwide  year
# 0  2018-03                 59  2018
# 1  2018-04                 61  2018
# 2  2018-05                 57  2018
# 3  2018-06                 56  2018
# 4  2018-07                 51  2018
# 5  2018-08                 58  2018
# 6  2018-09                 50  2018
# 7  2018-10                 49  2018
# 8  2018-11                 47  2018
# 9  2018-12                 48  2018
# 100
#       month  workout_worldwide  year
# 25  2020-04                100  2020
# 2020

# %%
# year_str with visualization
workout['year'] = workout['month'].str.split('-').str[0]
sns.lineplot(x='year', y='workout_worldwide', data=workout)
plt.show()

plt.plot(workout['year'], workout['workout_worldwide'])
plt.show()

# %%
# three_keywords.csv 
three_keywords = pd.read_csv('data/three_keywords.csv')
print(three_keywords.head(10))
print(three_keywords.dtypes)
# Out:
#      month  home_workout_worldwide  gym_workout_worldwide  home_gym_worldwide
# 0  2018-03                      12                     16                  10
# 1  2018-04                      12                     18                  10
# 2  2018-05                      13                     16                   9
# 3  2018-06                      12                     17                   9
# 4  2018-07                      12                     17                   9
# 5  2018-08                      12                     17                   9
# 6  2018-09                      11                     17                  10
# 7  2018-10                      11                     15                   9
# 8  2018-11                      11                     15                   9
# 9  2018-12                      11                     13                  10
# month                     object
# home_workout_worldwide     int64
# gym_workout_worldwide      int64
# ...

# %%
three_keywords['year'] = three_keywords['month'].str.split('-').str[0]
#print(three_keywords.head())

# three_keywords_2020

#home_workout_keywords_2020 = three_keywords['home_workout_worldwide'][three_keywords['year']=='2020'].max()
#print(home_workout_keywords_2020)
#gym_workout_keywords_2020 = three_keywords['gym_workout_worldwide'][three_keywords['year']=='2020'].max()
#print(gym_workout_keywords_2020)
#home_gym_keywords_2020 = three_keywords['home_gym_worldwide'][three_keywords['year']=='2020'].max()
#print(home_gym_keywords_2020)

three_keywords_2020_max = three_keywords[['home_workout_worldwide', 'gym_workout_worldwide', 'home_gym_worldwide']][three_keywords['year']=='2020'].max()
#print(three_keywords_2020_max)
#print(three_keywords_2020_max.idxmax())
peak_covid = three_keywords_2020_max.idxmax().split('_')[0] + " " + three_keywords_2020_max.idxmax().split('_')[1]
print(peak_covid)


# three_keywords_2023

#home_workout_keywords_2023 = three_keywords['home_workout_worldwide'][three_keywords['year']=='2023'].max()
#print(home_workout_keywords_2023)
#gym_workout_keywords_2023 = three_keywords['gym_workout_worldwide'][three_keywords['year']=='2023'].max()
#print(gym_workout_keywords_2023)
#home_gym_keywords_2023 = three_keywords['home_gym_worldwide'][three_keywords['year']=='2023'].max()
#print(home_gym_keywords_2023)

three_keywords_2023_max = three_keywords[['home_workout_worldwide', 'gym_workout_worldwide', 'home_gym_worldwide']][three_keywords['year']=='2023'].max()
#print(three_keywords_2023_max)
#print(three_keywords_2023_max.idxmax())
current = three_keywords_2023_max.idxmax().split('_')[0] + " " + three_keywords_2023_max.idxmax().split('_')[1]
print(current)
# Out:
# home workout
# gym workout

# %%
print(three_keywords.head(10))
print(three_keywords.dtypes)
three_keywords['year'] = three_keywords['year'].astype(int)
print(three_keywords.dtypes)

# Définir x et y après avoir changer year en int
x = three_keywords['year']
y1 = three_keywords['home_workout_worldwide']
y2 = three_keywords['gym_workout_worldwide']
y3 = three_keywords['home_gym_worldwide']

# Créer la figure
fig, ax = plt.subplots()
ax.plot(x, y1, label="Home Workout")
ax.plot(x, y2, label="Gym Workout")
ax.plot(x, y3, label="Home Gym")
# Créer les labels de chacun
ax.legend() 
plt.show()
# Out:
#      month  home_workout_worldwide  ...  home_gym_worldwide  year
# 0  2018-03                      12  ...                  10  2018
# 1  2018-04                      12  ...                  10  2018
# 2  2018-05                      13  ...                   9  2018
# 3  2018-06                      12  ...                   9  2018
# 4  2018-07                      12  ...                   9  2018
# 5  2018-08                      12  ...                   9  2018
# 6  2018-09                      11  ...                  10  2018
# 7  2018-10                      11  ...                   9  2018
# 8  2018-11                      11  ...                   9  2018
# 9  2018-12                      11  ...                  10  2018
#
# [10 rows x 5 columns]
# month                     object
# home_workout_worldwide     int64
# gym_workout_worldwide      int64
# home_gym_worldwide         int64
# year                      object
# dtype: object
# month                     object
# ...

# %%
# workout_geo.csv 
workout_geo = pd.read_csv('data/workout_geo.csv')
print(workout_geo.head(10))
print(workout_geo.dtypes)
# Out:
#                              country  workout_2018_2023
# 0                               Guam                NaN
# 1  Falkland Islands (Islas Malvinas)                NaN
# 2                       Cook Islands                NaN
# 3                             Brunei                NaN
# 4                              Palau                NaN
# 5                      United States              100.0
# 6                          Gibraltar                NaN
# 7           Northern Mariana Islands                NaN
# 8                     American Samoa                NaN
# 9                            Bermuda                NaN
# country               object
# workout_2018_2023    float64
# dtype: object

# %%
#three_country = ['United States', 'Australia', 'Japan']
#workout_geo_three_country = workout_geo[workout_geo['country'].isin(three_country)]
#print(workout_geo_three_country.head(5))
#top_country = workout_geo_three_country.max()
#print(top_country)

top_country = workout_geo[workout_geo['country'].isin(['United States', 'Australia', 'Japan'])].max().iloc[0]
#top_country = workout_geo.loc[workout_geo['country'].isin(['United States', 'Australia', 'Japan'])].max().iloc[0]
print(top_country)
# Out:
# United States

# %%
three_country_df = workout_geo[workout_geo["country"].isin(['United States', 'Australia', 'Japan'])]
print(three_country_df.head(4))
sns.barplot(x='country', y ='workout_2018_2023', data=three_country_df)
plt.show()
# Out:
#            country  workout_2018_2023
# 5    United States              100.0
# 18       Australia               77.0
# 216          Japan                1.0

# %%
# three_keywords_geo.csv
three_keywords_geo = pd.read_csv('data/three_keywords_geo.csv')
print(three_keywords_geo.head(10))
# Out:
#      Country  home_workout_2018_2023  gym_workout_2018_2023  home_gym_2018_2023
# 0  Gibraltar                     NaN                    NaN                 NaN
# 1    Lesotho                     NaN                    NaN                 NaN
# 2       Guam                     NaN                    NaN                 NaN
# 3   Botswana                     NaN                    NaN                 NaN
# 4     Brunei                     NaN                    NaN                 NaN
# 5     Bhutan                     NaN                    NaN                 NaN
# 6   Maldives                     NaN                    NaN                 NaN
# 7   Zimbabwe                     NaN                    NaN                 NaN
# 8      Malta                     NaN                    NaN                 NaN
# 9    Lebanon                     NaN                    NaN                 NaN

# %%
three_keywords_two_geo = three_keywords_geo[three_keywords_geo['Country'].isin(['Philippines','Malaysia'])]
print(three_keywords_two_geo[['Country', 'home_workout_2018_2023']].head())

home_workout_geo = three_keywords_two_geo['Country'][three_keywords_two_geo['home_workout_2018_2023'] == three_keywords_two_geo['home_workout_2018_2023'].max()].iloc[0]
print(home_workout_geo)
# Out:
#         Country  home_workout_2018_2023
# 23  Philippines                    52.0
# 61     Malaysia                    47.0
# Philippines
